# %%
import torch
import torch.nn as nn
import tqdm
import jieba
from torch.nn.utils import clip_grad_norm_

# %%
device=torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
class Dictionary(object):

    def __init__(self):
        self.word2idx={}
        self.idx2word={}
        self.idx=0

    def __len__(self):
        return len(self.word2idx)

    def add_word(self, word):
        if not word in self.word2idx:
            self.word2idx[word]=self.idx
            self.idx2word[self.idx]=word
            self.idx+=1

class Corpus(object):
    def __init__(self):
        self.dictionary=Dictionary()

    def get_data(self, path, batch_size=20):
        #step 1 
        with open(path, "r", encoding="utf-8") as f:
            tokens=0
            for line in f.readlines():
                words=jieba.lcut(line) + ['<eos>']
                tokens+=len(words)

                for word in words:
                    self.dictionary.add_word(word)

        
        ids=torch.LongTensor(tokens)
        token=0
        with open(path, "r", encoding="utf-8") as f:
            for line in f.readlines():
                words = jieba.lcut(line) + ['<eos>']
                for word in words:
                    ids[token] = self.dictionary.word2idx[word]
                    token += 1


        num_batches=ids.size(0)//batch_size
        ids=ids[:num_batches*batch_size]
        ids=ids.reshape(batch_size, -1)
        return ids

class LSTMmodel(nn.Module):

    def __init__(self, vocab_size, embed_size, hidden_size, num_layers) :
        super(LSTMmodel, self).__init__()
        self.embed=nn.Embedding(vocab_size, embed_size)
        self.lstm=nn.LSTM(embed_size, hidden_size, num_layers, batch_first=True)
        self.linear=nn.Linear(hidden_size, vocab_size)

    def forward(self, x, h):
        x=self.embed(x)
        out, (h,c)=self.lstm(x, h)
        out=out.reshape(out.size(0) * out.size(1), out.size(2))
        out=self.linear(out)

        return out, (h, c)

# %%
embed_size = 128
hidden_size = 1024
num_layers = 1
num_epochs = 5
batch_size = 50
seq_length = 30
learning_rate = 0.001

corpus=Corpus()

ids=corpus.get_data("C:/Python/PDF convetor\\Output.txt", batch_size)

vocab_size=len(corpus.dictionary)
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\blaze\AppData\Local\Temp\jieba.cache
# Loading model cost 0.379 seconds.
# Prefix dict has been built successfully.

# %%
print(vocab_size)

print(corpus.dictionary.word2idx)
# Out:
# 5306
# {'１': 0, '\n': 1, '<eos>': 2, ' ': 3, '「': 4, '所謂': 5, '完美': 6, '的': 7, '文章': 8, '並不': 9, '存在': 10, '，': 11, '就': 12, '像': 13, '絕望': 14, '不': 15, '一樣': 16, '。': 17, '」': 18, '當我': 19, '還是': 20, '大學生': 21, '時候': 22, '一位': 23, '偶然': 24, '認識': 25, '作家': 26, '這樣': 27, '對': 28, '我': 29, '說': 30, '雖然': 31, '能夠': 32, '理解': 33, '那': 34, '真正': 35, '含意': 36, '是': 37, '在': 38, '很': 39, '久': 40, '以': 41, '後': 42, '不過': 43, '至少': 44, '把': 45, '它': 46, '當做': 47, '某種': 48, '安慰': 49, '倒': 50, '可能': 51, '這': 52, '回事': 53, '但是': 54, '如此': 55, '每次': 56, '要': 57, '寫點': 58, '什麼': 59, '總是': 60, '被': 61, '氣氛': 62, '所': 63, '侵襲': 64, '因為': 65, '寫': 66, '領域': 67, '實在': 68, '太': 69, '有限': 70, '了': 71, '例如': 72, '假定': 73, '關於象': 74, '我能': 75, '點什麼': 76, '話': 77, '也': 78, '許對': 79, '馴象師': 80, '出來': 81, '就是': 82, '這麼': 83, '八年': 84, '之間': 85, '一直': 86, '左右': 87, '為': 88, '難': 89, '─': 90, '一段': 91, '漫長': 92, '歲': 93, '月': 94, '當然': 95, '只要': 96, '繼續': 97, '採取': 98, '一種': 99, '從': 100, '任何事物': 101, '都': 102, '能': 103, '學到': 104, '一點': 105, '東西': 106, '姿': 107, '態': 108, '年老': 109, '或': 110, '許並': 111, '怎麼': 112, '痛苦': 113, '這是': 114, '一般': 115, '論': 116, '自從': 117, '二十': 118, '剛過': 119, '不久': 120, '開始': 121, '努力': 122, '這種': 123, '生活': 124, '方式': 125, '因': 126, '此': 127, '承受': 128, '多少': 129, '次別': 130, '人給': 131, '重大': 132, '打擊': 133, '、': 134, '欺騙': 135, '誤解': 136, '而': 137, '同時': 138, '經歷': 139, '許多': 140, '不可': 141, '思議': 142, '體驗': 143, '各式': 144, '各樣': 145, '人': 146, '跑': 147, '來': 148, '告訴': 149, '事情': 150, '正如': 151, '走過': 152, '一': 153, '座橋': 154, '發出': 155, '聲音': 156, '身上': 157, '通過': 158, '而且': 159, '從此': 160, '不再': 161, '回來': 162, '那期': 163, '間': 164, '緊閉': 165, '著': 166, '嘴巴': 167, '沒': 168, '情況': 169, '下': 170, '迎接': 171, '歲代': 172, '最': 173, '一年': 174, '現在': 175, '想': 176, '問題': 177, '依然': 178, '一個': 179, '解決': 180, '完以': 181, '許事態': 182, '仍然': 183, '完全相同': 184, '結果': 185, '並': 186, '不是': 187, '自我': 188, '療養': 189, '手段': 190, '只': 191, '做': 192, '微小': 193, '嘗試': 194, '而已': 195, '得': 196, '坦白': 197, '真': 198, '誠': 199, '卻': 200, '非常': 201, '困難': 202, '越': 203, '實話': 204, '正確': 205, '的語': 206, '言': 207, '沉到': 208, '黑暗': 209, '深處': 210, '去': 211, '我並': 212, '不想': 213, '辯解': 214, '裏': 215, '現': 216, '最佳': 217, '狀態': 218, '需要': 219, '附加': 220, '：': 221, '搞不好': 222, '很久': 223, '幾': 224, '年': 225, '十年': 226, '可以': 227, '發現': 228, '得救': 229, '自己': 230, '那時候': 231, '大象': 232, '回到': 233, '平原': 234, '用': 235, '比': 236, '所用': 237, '更': 238, '美好': 239, '語言': 240, '談論': 241, '這個': 242, '世界': 243, '◇': 244, '關於': 245, '大部分': 246, '跟': 247, '戴': 248, '立克': 249, '．': 250, '哈德': 251, '費爾學': 252, '許應': 253, '該': 254, '全': 255, '部': 256, '不幸': 257, '費爾': 258, '各': 259, '方面': 260, '毛': 261, '要讀': 262, '知道': 263, '難讀': 264, '故事': 265, '雜亂': 266, '主題': 267, '笨拙': 268, '幼稚': 269, '如': 270, '他': 271, '畢竟': 272, '戰鬥': 273, '武器': 274, '少數': 275, '非凡': 276, '之一': 277, '即使': 278, '和': 279, '海明威': 280, '費滋傑': 281, '羅': 282, '等': 283, '同時代': 284, '為伍': 285, '那種': 286, '勢': 287, '絕不落': 288, '唯一': 289, '遺憾': 290, '費爾到': 291, '不能': 292, '明確': 293, '掌握': 294, '對象': 295, '形象': 296, '就是指': 297, '這點': 298, '兩個': 299, '然': 300, '死去': 301, '一九三八年': 302, '六': 303, '某個': 304, '晴朗': 305, '星期天': 306, '早晨': 307, '右手': 308, '抱著': 309, '希特勒': 310, '肖像': 311, '左手': 312, '撐': 313, '把傘': 314, '從帝': 315, '國大廈': 316, '屋頂': 317, '跳': 318, '下來': 319, '活著': 320, '死': 321, '造成': 322, '不得了': 323, '話題': 324, '得到': 325, '第一本': 326, '已經': 327, '絕版': 328, '書': 329, '大腿': 330, '嚴重': 331, '皮膚': 332, '病': 333, '初三': 334, '暑假': 335, '給我': 336, '那本書': 337, '叔叔': 338, '三年': 339, '腸癌': 340, '身變': 341, '支離': 342, '破碎': 343, '身體': 344, '入口': 345, '出口': 346, '插滿': 347, '塑膠': 348, '管': 349, '那樣': 350, '到': 351, '最後見': 352, '隻': 353, '狡猾': 354, '猴子': 355, '焦焦': 356, '紅紅': 357, '縮成': 358, '一小': 359, '團': 360, '一共': 361, '有三個': 362, '上海': 363, '郊外': 364, '戰爭': 365, '結束': 366, '兩天': 367, '踩': 368, '埋': 369, '地雷': 370, '只有': 371, '第三': 372, '個': 373, '還活': 374, '當了': 375, '魔術師': 376, '全國': 377, '溫泉': 378, '地': 379, ' ...

# %%
print(ids)
# Out:
# tensor([[   0,    1,    2,  ...,  314,   11,  315],
#         [ 316,    7,  317,  ...,   52,    1,    2],
#         [ 537,   17,    1,  ...,   18,    7,  641],
#         ...,
#         [4993,   29,  662,  ...,    4,    3, 5094],
#         [   3, 5095,    1,  ..., 1948,   17, 3201],
#         [ 271,  173, 3211,  ...,    3,   90,   90]])

# %%
print(ids.shape)
# Out:
# torch.Size([50, 705])

# %%
model=LSTMmodel(vocab_size, embed_size, hidden_size, num_layers).to(device)
cost=nn.CrossEntropyLoss()
optimizer=torch.optim.AdamW(model.parameters(), lr=learning_rate)

# %%
for epoch in range(num_epochs):

    states = (torch.zeros(num_layers, batch_size, hidden_size).to(device),
              torch.zeros(num_layers, batch_size, hidden_size).to(device))

    for i in range(0, ids.size(1) - seq_length, seq_length):
        inputs = ids[:, i:i+seq_length].to(device)
        targets = ids[:, (i+1):(i+1)+seq_length].to(device)

        states = [state.detach() for state in states]
        outputs, states = model(inputs, states)
        loss = cost(outputs, targets.reshape(-1))

        model.zero_grad()
        optimizer.zero_grad()
        loss.backward()
        
        optimizer.step()
        clip_grad_norm_(model.parameters(), 0.5)

        if i%30==0:
            print(f'Epoch [{epoch+1}/{num_epochs}], Step [{i}], Loss: {loss.item():.4f}')
# Out:
# Epoch [1/5], Step [0], Loss: 8.5875
# Epoch [1/5], Step [30], Loss: 8.4841
# Epoch [1/5], Step [60], Loss: 8.3372
# Epoch [1/5], Step [90], Loss: 7.8719
# Epoch [1/5], Step [120], Loss: 6.6395
# Epoch [1/5], Step [150], Loss: 6.0287
# Epoch [1/5], Step [180], Loss: 5.9997
# Epoch [1/5], Step [210], Loss: 5.9112
# Epoch [1/5], Step [240], Loss: 5.7028
# Epoch [1/5], Step [270], Loss: 5.8815
# Epoch [1/5], Step [300], Loss: 6.0635
# Epoch [1/5], Step [330], Loss: 6.0344
# Epoch [1/5], Step [360], Loss: 5.7675
# Epoch [1/5], Step [390], Loss: 5.7817
# Epoch [1/5], Step [420], Loss: 5.7130
# Epoch [1/5], Step [450], Loss: 5.9336
# Epoch [1/5], Step [480], Loss: 5.6847
# Epoch [1/5], Step [510], Loss: 5.6506
# Epoch [1/5], Step [540], Loss: 5.8739
# Epoch [1/5], Step [570], Loss: 5.4332
# Epoch [1/5], Step [600], Loss: 5.5471
# Epoch [1/5], Step [630], Loss: 5.5482
# Epoch [1/5], Step [660], Loss: 5.5144
# Epoch [2/5], Step [0], Loss: 5.8934
# Epoch [2/5], Step [30], Loss: 5.7167
# Epoch [2/5], Step [60], Loss: 5.6238
# Epoch [2/5], Step [90], Loss: 5.3986
# Epoch [2/5], Step [120], Loss: 5.1538
# Epoch [2/5], Step [150], Loss: 5.1361
# Epoch [2/5], Step [180], Loss: 5.1859
# Epoch [2/5], Step [210], Loss: 5.0626
# Epoch [2/5], Step [240], Loss: 4.7306
# Epoch [2/5], Step [270], Loss: 5.0040
# Epoch [2/5], Step [300], Loss: 5.3161
# Epoch [2/5], Step [330], Loss: 5.3045
# Epoch [2/5], Step [360], Loss: 5.0247
# Epoch [2/5], Step [390], Loss: 5.1322
# Epoch [2/5], Step [420], Loss: 5.0784
# Epoch [2/5], Step [450], Loss: 5.3331
# Epoch [2/5], Step [480], Loss: 5.0687
# Epoch [2/5], Step [510], Loss: 5.1092
# Epoch [2/5], Step [540], Loss: 5.3524
# Epoch [2/5], Step [570], Loss: 4.8723
# Epoch [2/5], Step [600], Loss: 5.0323
# Epoch [2/5], Step [630], Loss: 5.0254
# Epoch [2/5], Step [660], Loss: 5.0050
# Epoch [3/5], Step [0], Loss: 5.4182
# Epoch [3/5], Step [30], Loss: 5.2183
# Epoch [3/5], Step [60], Loss: 5.0745
# Epoch [3/5], Step [90], Loss: 4.9310
# Epoch [3/5], Step [120], Loss: 4.8607
# Epoch [3/5], Step [150], Loss: 4.9324
# Epoch [3/5], Step [180], Loss: 4.9886
# Epoch [3/5], Step [210], Loss: 4.8885
# Epoch [3/5], Step [240], Loss: 4.5215
# Epoch [3/5], Step [270], Loss: 4.8236
# Epoch [3/5], Step [300], Loss: 5.1285
# Epoch [3/5], Step [330], Loss: 5.1084
# Epoch [3/5], Step [360], Loss: 4.8078
# Epoch [3/5], Step [390], Loss: 4.9021
# Epoch [3/5], Step [420], Loss: 4.8411
# Epoch [3/5], Step [450], Loss: 5.0989
# Epoch [3/5], Step [480], Loss: 4.8429
# Epoch [3/5], Step [510], Loss: 4.8788
# Epoch [3/5], Step [540], Loss: 5.1241
# Epoch [3/5], Step [570], Loss: 4.6288
# Epoch [3/5], Step [600], Loss: 4.8010
# Epoch [3/5], Step [630], Loss: 4.7872
# Epoch [3/5], Step [660], Loss: 4.7608
# Epoch [4/5], Step [0], Loss: 5.1676
# Epoch [4/5], Step [30], Loss: 4.9735
# Epoch [4/5], Step [60], Loss: 4.8466
# Epoch [4/5], Step [90], Loss: 4.7084
# Epoch [4/5], Step [120], Loss: 4.6473
# Epoch [4/5], Step [150], Loss: 4.7297
# Epoch [4/5], Step [180], Loss: 4.8018
# Epoch [4/5], Step [210], Loss: 4.7020
# Epoch [4/5], Step [240], Loss: 4.3357
# Epoch [4/5], Step [270], Loss: 4.6158
# Epoch [4/5], Step [300], Loss: 4.8860
# Epoch [4/5], Step [330], Loss: 4.8709
# Epoch [4/5], Step [360], Loss: 4.6043
# Epoch [4/5], Step [390], Loss: 4.6930
# Epoch [4/5], Step [420], Loss: 4.6050
# Epoch [4/5], Step [450], Loss: 4.8658
# Epoch [4/5], Step [480], Loss: 4.6382
# Epoch [4/5], Step [510], Loss: 4.6513
# Epoch [4/5], Step [540], Loss: 4.9029
# Epoch [4/5], Step [570], Loss: 4.4140
# Epoch [4/5], Step [600], Loss: 4.6107
# Epoch [4/5], Step [630], Loss: 4.5945
# Epoch [4/5], Step [660], Loss: 4.5693
# Epoch [5/5], Step [0], Loss: 4.9532
# Epoch [5/5], Step [30], Loss: 4.7713
# Epoch [5/5], Step [60], Loss: 4.6394
# Epoch [5/5], Step [90], Loss: 4.5015
# Epoch [5/5], Step [120], Loss: 4.4562
# Epoch [5/5], Step [150], Loss: 4.5231
# Epoch [5/5], Step [180], Loss: 4.6040
# Epoch [5/5], Step [210], Loss: 4.5029
# Epoch [5/5], Step [240], Loss: 4.1414
# Epoch [5/5], Step [270], Loss: 4.4169
# Epoch [5/5], Step [300], Loss: 4.6744
# Epoch [5/5], Step [330], Loss: 4.6551
# Epoch [5/5], Step [360], Loss: 4.3850
# Epoch [5/5], Step [390], Loss: 4.4757
# Epoch [5/5], Step [420], Loss: 4.3943
# Epoch [5/5], Step [450], Loss: 4.6375
# Epoch [5/5], Step [480], Loss: 4.4202
# Epoch [5/5], Step [510], Loss: 4.4301
# Epoch [5/5], Step [540], Loss: 4.7023
# Epoch [5/5], Step [570], Loss: 4.2135
# Epoch [5/5], Step [600], Loss: 4.3982
# Epoch [5/5], Step [630], Loss: 4.3741
# Epoch [5/5], Step [660], Loss: 4.3627

# %%
num_samples = 300

article = str()

state = (torch.zeros(num_layers, 1, hidden_size).to(device),
        torch.zeros(num_layers, 1, hidden_size).to(device))

prob = torch.ones(vocab_size)
_input = torch.multinomial(prob, num_samples=1).unsqueeze(1).to(device)

print(prob)
print(_input.shape)
# Out:
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# torch.Size([1, 1])

# %%
for i in range(num_samples):
    output, state = model(_input, state)

    prob = output.exp()
    word_id = torch.multinomial(prob, num_samples=1).item()

    _input.fill_(word_id)

    word = corpus.dictionary.idx2word[word_id]
    word = '\n' if word == '<eos>' else word
    article += word
print(article)
# Out:
# 威士忌大部分內想問仇下水道西沒開店這才語問如下司機械式市政府後說，一扇算了滿滿
#
# 錶家庭八點的怪癖倒開始星期天。老鼠被心無法
#
# 五分。她：的。
#
#   「真的我呢啊。」
#
#   「好心情？」
#
#   「她比的夢妳飛機人瀰。」
#
#   我Revival拿收音嗎？」
#
#   「不用 ◇，毫無意。」
#
#    我點個的稍微裏，受傷的作家毛巾，會木板錶，會後
#
# 變色嗎的，嘆是還做著，轉動是沒話希
#
#   老鼠把你在奏曲而將怎麼樣要領帶代替後的汗，六學生從的那種我覺運氣壞圓。我
#
#   「California一點在三點吧的初三的，，你習慣是妳好在不想的記得得湊巧的
#
# 昏裏不治之症來
#
#  … 出生─巴斯德高中生的話。密修雷話？一個人開都回答的《很無聊，還是餐具的臉第六，有些路邊什麼的觸角。
#
#   我在會變楞，有再了話。」
#
#   什麼食物了。」
#
#   「再比一瓶走要死是行十二月再的老電影嗎？」
#
#   我如此」
#
# 瞪     ◇ …… …）
